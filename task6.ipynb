# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv

# %%
import matplotlib.pyplot as plt
from scipy.stats  import binom
import numpy as np
n=12
p=0.6
k=10
prob=binom.pmf(k,n,p)#shows highest possibilty is 0.06  which means 60% chance for sucess
print(prob)
# Out:
# 0.06385228185600002

# %%
import matplotlib.pyplot as plt
from scipy.stats import binom
import numpy as np
n=25
p=0.6
k=15
probablity=binom.pmf(k,n,p)
print(probablity)
# Out:
# 0.16115793869486383

# %%
from scipy.stats import binom
n=12
p=0.6
k=10
p=binom.cdf(n,k,p)
print(p)
# Out:
# 1.0

# %%
from scipy.stats import binom
n=12
p=0.6
k=10
p=binom.cdf(k,n,p)
print(p)
# Out:
# 0.980408958976

# %%
from scipy.stats import zscore
# Data values
data = [10, 20, 30, 40, 50]
# Automatic Z-score calculation
result = zscore(data)
print("Data:", data)
print("Z-scores:", result)
# Out:
# Data: [10, 20, 30, 40, 50]
# Z-scores: [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]

# %%
from scipy.stats import zscore
data=[50,60,70,80,90]
result=zscore(data)
print(data)
print(result)
# Out:
# [50, 60, 70, 80, 90]
# [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]

# %%
data=pd.read_csv("/content/ipl_data.csv")
data
# Out:
#        mid        date                                      venue  \
# 0        1  2008-04-18                      M Chinnaswamy Stadium
# 1        1  2008-04-18                      M Chinnaswamy Stadium
# 2        1  2008-04-18                      M Chinnaswamy Stadium
# 3        1  2008-04-18                      M Chinnaswamy Stadium
# 4        1  2008-04-18                      M Chinnaswamy Stadium
# ...    ...         ...                                        ...
# 76009  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76010  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76011  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76012  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
# 76013  617  2017-05-21  Rajiv Gandhi International Stadium, Uppal
#
#                     bat_team                    bowl_team      batsman  \
# 0      Kolkata Knight Riders  Royal Challengers Bangalore   SC Ganguly
# ...

# %%
df=data["date"]
df
# Out:
# 0        2008-04-18
# 1        2008-04-18
# 2        2008-04-18
# 3        2008-04-18
# 4        2008-04-18
#             ...
# 76009    2017-05-21
# 76010    2017-05-21
# 76011    2017-05-21
# 76012    2017-05-21
# 76013    2017-05-21
# Name: date, Length: 76014, dtype: object

# %%
data["bowl_team"]
# Out:
# 0        Royal Challengers Bangalore
# 1        Royal Challengers Bangalore
# 2        Royal Challengers Bangalore
# 3        Royal Challengers Bangalore
# 4        Royal Challengers Bangalore
#                     ...
# 76009         Rising Pune Supergiant
# 76010         Rising Pune Supergiant
# 76011         Rising Pune Supergiant
# 76012         Rising Pune Supergiant
# 76013         Rising Pune Supergiant
# Name: bowl_team, Length: 76014, dtype: object

# %%
data=pd.read_csv("/content/StudentPerformanceFactors.csv")
data
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
x=data["Hours_Studied"]
x
# Out:
# 0       23
# 1       19
# 2       24
# 3       29
# 4       19
#         ..
# 6602    25
# 6603    23
# 6604    20
# 6605    10
# 6606    15
# Name: Hours_Studied, Length: 6607, dtype: int64

# %%
y=data["Exam_Score"]
y
# Out:
# 0       67
# 1       61
# 2       74
# 3       71
# 4       70
#         ..
# 6602    68
# 6603    69
# 6604    68
# 6605    68
# 6606    64
# Name: Exam_Score, Length: 6607, dtype: int64

# %%
coffecient=np.corrcoef(x,y)

# %%
print(coffecient)
# Out:
# [[1.         0.44545495]
#  [0.44545495 1.        ]]

# %%
r=coffecient[0,1]
print("corelational cofficient is:",r)
# Out:
# corelational cofficient is: 0.44545495407528235

# %%
import math
Z = 1.96
sigma = 10
n = 100
ME = Z * (sigma / math.sqrt(n))
print("Margin of Error =", ME)
# Out:
# Margin of Error = 1.96

# %%
import math
z=1.96
sig=10
n=50
me=z*(sig/math.sqrt(n))
print(me)
# Out:
# 2.771858582251266

# %%
import numpy as np
# Example dataset
hours = np.array([1, 2, 3, 4, 5])
marks = np.array([30, 40, 50, 65, 80])
# Correlation matrix
r_matrix = np.corrcoef(hours, marks)
# Extract r value
r = r_matrix[0, 1]
print("Correlation coefficient (r):", r)
# Out:
# Correlation coefficient (r): 0.9944466052196624

# %%
import numpy as np
hours=np.array([5,6,7,8,10])
marks=np.array([50,60,77,80,99])
r_matrix=np.corrcoef(hours,marks)
r=r_matrix[0,1]
print(r)
# Out:
# 0.9854346156046278
